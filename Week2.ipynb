# %% [markdown]
# <a href="https://colab.research.google.com/github/MRayhanAP/MRayhanAP-PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv 
from google.colab.patches import cv2_imshow 
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np 
img = cv.imread('/content/drive/MyDrive/01kitten.png')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/01kitten.png', cv.IMREAD_GRAYSCALE) 
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/01kitten.png',img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))		#ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices

pts = vertices.reshape((-1,1,2))		#nilai 2 untuk menunjukan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts

cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#Tugas 1

plt.figure(figsize=(3,3))
plt.imshow(img3)

# %%
#Tugas 2

#Red - Green
img4 = img3
img4[:,:,0] = np.zeros([img4.shape[0], img4.shape[1]])
plt.imshow(img4)

# %%
#Tugas 2

#Blue - Green
img5 = img3

img5[:,:,2] = np.zeros([img5.shape[0], img5.shape[1]])
plt.imshow(img5)

# %%
#Tugas 3

img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3[10:100, 10:100])

# %%
#Tugas 4

plt.imshow(img5[5:30])

# %%
#Tugas 5
import random

img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
n = 0
while (n < 5):
  k1 = random.randint(0,559)
  k2 = random.randint(0,559)
  kotak = cv.rectangle(img6, pt1=(k1, k1), pt2=(k2, k2), color=(k1, k2, random.randint(0,255)),thickness=5)
  n+=1
# Displaying the image  
plt.imshow(img6)

# %%
#Tugas 6

img7 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
plt.imshow(img7)

# %%
img5 = cv.cvtColor(img,cv.COLOR_BGR2RGB)


fig = plt.figure(figsize = (5,5))
ax = fig.add_subplot(111) 

cv.rectangle(img5,pt1=(150,190),pt2=(450,450),color=(0,255,0), thickness=2)
cv.circle(img5,center=(300,280),radius=160,color=(255,0,0),thickness=2)

ax.imshow(img5)

# %%
img5 = cv.cvtColor(img,cv.COLOR_BGR2RGB)

fig = plt.figure(figsize = (5,5))
ax = fig.add_subplot(111) 
cv.rectangle(img5,pt1=(10,530),pt2=(180,590),color=(0,0,255), thickness=2)


ax.imshow(img5)

# %%
img5 = cv.cvtColor(img,cv.COLOR_BGR2RGB)

fig = plt.figure(figsize = (5,5))
ax = fig.add_subplot(111) 
cv.rectangle(img5,pt1=(10,530),pt2=(180,590),color=(0,0,255), thickness=2)
cv.putText(img5, text='OWO',org=(20,580),fontFace=font,fontScale=2,color=(255,0,0),thickness=2,lineType=cv.LINE_AA)

ax.imshow(img5)
